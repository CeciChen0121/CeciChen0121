# %% [markdown]
# <a href="https://colab.research.google.com/github/CeciChen0121/CeciChen0121/blob/main/QTM250_Group6_HW_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![cred-alex-bailey-for-twentieth-c-fox_wide-0b9306aa3b0c130bb2782db974bd31e33db5687b-s1100-c50.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **The Babies of Bohemian Rhapsody

# %% [markdown]
# ## Data Source
# [USA Names dataset](https://console.cloud.google.com/marketplace/details/social-security-administration/us-names?project=atomic-affinity-342015)

# %% [markdown]
# ## Processed Data
#
# [Processed Data in Google Speadsheet](https://docs.google.com/spreadsheets/d/1qT1xHLwDSnTf2vYtgLLgNaFYDD3bnLJrCvBtorMt3iY/edit?usp=sharing)

# %% [markdown]
# ## Queries
# [Queries on Google Cloud Platform](https://console.cloud.google.com/bigquery?sq=593842312333:7ff96f31724048fabe8f59a8919e1ff3)

# %% [markdown]
# ![Graph "Total Number of Name "Rami" Used in the U.S. by Year"](https://docs.google.com/spreadsheets/d/e/2PACX-1vTIet_1frl-WK3uZndYXgJgIyMXrkkGj-JfAdDR_HEEuvhu9Kzir8Sw_Q3wmKwQbPntTwDfkmk4c3mD/pubchart?oid=732147547&format=interactive)

# %%
# Out:
#   File "<ipython-input-1-0fc4dc30ace4>", line 3
#     sum(number) AS total
#                  ^
# SyntaxError: invalid syntax

# %% [markdown]
# Based on the populatity of the movie Bohemian Rhapsody we would expect to see an increse in the actor bohemian rhapsody
